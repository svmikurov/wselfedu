# %%
from english.models import WordModel, WordUserKnowledgeRelation

# %%
user_id = 1
category_id = 8
source_id = 7

# %%
words = WordModel.objects.filter(
    category_id=category_id,
    source_id=source_id,
)
words
# Out:
# <QuerySet [<WordModel: let objects customize>, <WordModel: attribute lookup, storage, and deletion>, <WordModel: major>, <WordModel: a basic overview>, <WordModel: moving gently from>, <WordModel: adding one feature at a time>, <WordModel: shows a complete, practical descriptor example>, <WordModel: goes into the detailed mechanics of how descriptors work>, <WordModel: pure Python>, <WordModel: equivalents>, <WordModel: curious about how>, <WordModel: how functions turn>, <WordModel: bound methods>, <WordModel: about the implementation of common tools>, <WordModel: like>, <WordModel: primer>, <WordModel: most basic possible example>, <WordModel: capabilities>, <WordModel: one by one>, <WordModel: descriptor whose __get__() method>, '...(remaining elements truncated)...']>

# %%
    user_knowledge_words_pk =  WordUserKnowledgeRelation.objects.filter(
        user=UserModel.objects.get(pk=user_id),
    ).filter(
        knowledge_assessment__lte=0
    ).values_list("word_id", flat=True)
    
    user_knowledge_words_pk
# Out:
# <QuerySet [406, 403, 397, 410, 404, 411, 408, 526, 529, 434, 446, 449, 521, 452, 499, 478, 525, 457, 463, 490, '...(remaining elements truncated)...']>

# %%
    for word_id in user_knowledge_words_pk:
        print(word_id)
# Out:
# 406
# 403
# 397
# 410
# 404
# 411
# 408
# 526
# 529
# 434
# 446
# 449
# 521
# 452
# 499
# 478
# 525
# 457
# 463
# 490
# 431
# 498
# 522
# 530
# 513
# 484
# 450
# 461
# 462
# 473
# 455
# 505
# 438
# 514
# 488
# 458
# 474
# 531
# 465
# 512
# 527
# 469
# 436
# 467
# 439
# 510
# 480
# 477
# 443
# 471
# 503
# 437
# 491
# 427
# 507
# 460
# 520
# 447
# 453
# 518
# 506
# 479
# 489
# 509
# 528
# 523
# 511
# 482
# 435
# 426
# 428
# 504
# 487
# 493
# 500
# 466
# 501
# 440
# 492
# 476
# 519
# 486
# 454
# 485
# 483
# 400
# 83
# 106
# 117
# 159
# 343
# 80
# 183
# 101
# 178
# 441
# 87
# 363
# 113
# 348
# 130
# 147
# 401
# 182
# 425
# 97
# 86
# 144
# 423
# 353
# 432
# 424
# 181
# 138
# 94
# 121
# 89
# 122
# 137
# 375
# 177
# 92
# 77
# 358
# 366
# 164
# 157
# 412
# 11
# 226
# 194
# 193
# 405
# 299
# 341
# 175
# 131
# 58
# 224
# 39
# 209
# 395
# 102
# 272
# 318
# 172
# 67
# 275
# 206
# 314
# 305
# 148
# 171
# 10
# 388
# 270
# 125
# 383
# 262
# 141
# 241
# 421
# 201
# 317
# 385
# 354
# 327
# 464
# 352
# 409
# 239
# 276
# 203
# 369
# 71
# 32
# 70
# 60
# 236
# 168
# 280
# 335
# 337
# 228
# 156
# 35
# 36
# 339
# 297
# 210
# 129
# 252
# 433
# 143
# 145
# 154
# 107
# 311
# 258
# 169
# 315
# 381
# 334
# 69
# 81
# 14
# 370
# 277
# 166
# 365
# 59
# 347
# 419
# 373
# 414
# 524
# 402
# 413
# 417
# 448
# 420
# 398
# 415
# 399
# 442
# 418
# 384
# 207
# 100
# 259
# 108
# 382
# 142
# 155
# 225
# 22
# 12
# 26
# 329
# 128
# 195
# 324
# 111
# 65
# 316
# 118
# 221
# 351
# 359
# 291
# 208
# 16
# 378
# 152
# 282
# 174
# 376
# 211
# 346
# 326
# 379
# 304
# 255
# 56
# 216
# 298
# 190
# 134
# 322
# 231
# 371
# 233
# 331
# 295
# 25
# 173
# 245
# 294
# 309
# 191
# 392
# 205
# 165
# 288
# 133
# 135
# 73
# 109
# 99
# 189
# 185
# 243
# 146
# 2
# 199
# 180
# 153
# 43
# 160
# 223
# 286
# 140
# 380
# 161
# 68
# 123
# 336
# 17
# 332
# 127
# 302
# 344
# 200
# 248
# 6
# 284
# 342
# 187
# 310
# 349
# 237
# 257
# 132
# 124
# 289
# 197
# 120
# 306
# 268
# 19
# 18
# 214
# 391
# 136
# 222
# 63
# 220
# 213
# 238
# 278
# 307
# 296
# 184
# 139
# 114
# 230
# 345
# 198
# 95
# 263
# 269
# 79
# 364
# 151
# 244
# 271
# 249
# 319
# 170
# 55
# 163
# 88
# 98
# 74
# 72

# %%
    words_id_for_choice = []
    for word_bj in words:
        if word_bj.pk in user_knowledge_words_pk:
            words_id_for_choice.append(word_bj)
    
    words_id_for_choice
# Out:
# [<WordModel: let objects customize>,
#  <WordModel: attribute lookup, storage, and deletion>,
#  <WordModel: major>,
#  <WordModel: adding one feature at a time>,
#  <WordModel: shows a complete, practical descriptor example>,
#  <WordModel: goes into the detailed mechanics of how descriptors work>,
#  <WordModel: pure Python>,
#  <WordModel: equivalents>,
#  <WordModel: curious about how>,
#  <WordModel: how functions turn>,
#  <WordModel: bound methods>,
#  <WordModel: about the implementation of common tools>,
#  <WordModel: like>,
#  <WordModel: primer>,
#  <WordModel: one by one>,
#  <WordModel: descriptor whose __get__() method>,
#  <WordModel: To use the descriptor>,
#  <WordModel: it must be stored>,
#  <WordModel: Normal attribute lookup>,
#  <WordModel: Descriptor lookup>,
#  <WordModel: the dot operator finds>,
#  <WordModel: recognized by its __get__ method>,
#  <WordModel: is not stored in either the class dictionary>,
#  <WordModel: Instead, the value 10 is computed on demand.>,
#  <WordModel: but it isn’t very useful>,
#  <WordModel: For retrieving constants>,
#  <WordModel: Besides showing how>,
#  <WordModel: can run computations>,
#  <WordModel: reveals the purpose of the parameters to>,
#  <WordModel: reveals>,
#  <WordModel: the purpose>,
#  <WordModel: that lets>,
#  <WordModel: Managed attribute>,
#  <WordModel: assigned>,
#  <WordModel: to a public attribute>,
#  <WordModel: while the actual data>,
#  <WordModel: The descriptor’s methods>,
#  <WordModel: are triggered when the public attribute is accessed>,
#  <WordModel: is triggered>,
#  <WordModel: When the public attribute is accessed>,
#  <WordModel: the descriptor logs the lookup or update>,
#  <WordModel: calls both ... and ...>,
#  <WordModel: The initial age update is logged>,
#  <WordModel: The actual data is in a private attribute>,
#  <WordModel: Access the data and log the lookup>,
#  <WordModel: Updates are logged as well>,
#  <WordModel: as well>,
#  <WordModel: Regular attribute lookup isn't logged>,
#  <WordModel: Regular attribute lookup>,
#  <WordModel: One major issue with this example is that>,
#  <WordModel: is hardwired in the>,
#  <WordModel: logged attribute>,
#  <WordModel: unchangeable>,
#  <WordModel: into the detailed mechanics of>,
#  <WordModel: this level of detail>,
#  <WordModel: attribute lookup>,
#  <WordModel: Descriptor instance>,
#  <WordModel: Besides>,
#  <WordModel: showing>,
#  <WordModel: the target directory>,
#  <WordModel: is assigned to>,
#  <WordModel: a public attribute>,
#  <WordModel: Descriptor HowTo Guide>,
#  <WordModel: typically>,
#  <WordModel: Accessing 'age' giving 30>,
#  <WordModel: Logged Access>,
#  <WordModel: logs access to>,
#  <WordModel: The new class now logs access to both name and age>,
#  <WordModel: even>,
#  <WordModel: get invoked>,
#  <WordModel: indirectly>,
#  <WordModel: If a descriptor is accessed indirectly with>,
#  <WordModel: When put in instances>,
#  <WordModel: Traditionally>,
#  <WordModel: the calling class controls what>,
#  <WordModel: happens>,
#  <WordModel: Descriptors invert that relationship>,
#  <WordModel: relationship>,
#  <WordModel: allow the data being looked-up>,
#  <WordModel: to have a say in the matter>,
#  <WordModel: throughout the language>,
#  <WordModel: It is how>]
